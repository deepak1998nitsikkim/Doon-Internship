# %%
# 1. Single Inheritance Example
class Animal:
    def sound(self):
        print("This animal makes a sound")

class Dog(Animal):
    def bark(self):
        print("Dog barks")

d = Dog()
d.sound()
d.bark()

# %%
# 2. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 3. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 4. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 5. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 6. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 7. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 8. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 9. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 10. Multilevel Inheritance
class A:
    def show(self):
        print("Class A")

class B(A):
    def display(self):
        print("Class B")

class C(B):
    def print_msg(self):
        print("Class C")

obj = C()
obj.show()
obj.display()
obj.print_msg()

# %%
# 11. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 12. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 13. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 14. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 15. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 16. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 17. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 18. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 19. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 20. Multiple Inheritance
class A:
    def feature1(self):
        print("Feature 1 from A")

class B:
    def feature2(self):
        print("Feature 2 from B")

class C(A, B):
    def feature3(self):
        print("Feature 3 from C")

obj = C()
obj.feature1()
obj.feature2()
obj.feature3()

# %%
# 21. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 22. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 23. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 24. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 25. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 26. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 27. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 28. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 29. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 30. Hierarchical Inheritance
class Parent:
    def show(self):
        print("Parent class")

class Child1(Parent):
    def feature1(self):
        print("Child1 feature")

class Child2(Parent):
    def feature2(self):
        print("Child2 feature")

obj1 = Child1()
obj2 = Child2()
obj1.show()
obj1.feature1()
obj2.show()
obj2.feature2()

# %%
# 31. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 32. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 33. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 34. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 35. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 36. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 37. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 38. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 39. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 40. Hybrid Inheritance
class A:
    def method_A(self):
        print("Method A")

class B(A):
    def method_B(self):
        print("Method B")

class C(A):
    def method_C(self):
        print("Method C")

class D(B, C):
    def method_D(self):
        print("Method D")

obj = D()
obj.method_A()
obj.method_B()
obj.method_C()
obj.method_D()

# %%
# 41. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 42. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 43. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 44. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 45. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 46. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 47. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 48. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 49. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()

# %%
# 50. Real-world Example - Employee Hierarchy
class Employee:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Employee:", self.name)

class Manager(Employee):
    def role(self):
        print("Role: Manager")

class Developer(Employee):
    def role(self):
        print("Role: Developer")

m = Manager("Alice")
d = Developer("Bob")
m.show()
m.role()
d.show()
d.role()
